# %% [markdown]
# ## 開發環境控制

# %% [markdown]
# + 看目前的環境有哪些</br>
# conda env list
#
# + 創環境；–n後面填自己要的名字(ex:my_env)；最後面可以指定版本 </br>
# conda create –name my_env python=3.6
#
# + 進入環境
#     + windows </br>
#      activate my_env
#     + macOS/linux </br>
#     source activate my_env
#
# + 離開環境</br>
#     + windows </br>
#     conda deactivate
#     + macOS/linux </br>
#     source deactivate
#
# + 刪掉環境裡面的某個套件
# conda remove --name my_env numpy
#
# + 刪掉整個環境
# conda env remove --name my_env

# %%
from pdfminer.pdfpage import PDFPage
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from io import StringIO 

pdf_path = 'D:/coding_resource/fourth_grade/politic_python/code/1_temp/code_mine/517_code/KCC Data/input/1-1-1000516-1-蘇炎城.pdf'
with open(pdf_path, 'rb') as fh:
    for page in PDFPage.get_pages(fh, caching=True, check_extractable=True):
        resource_manager = PDFResourceManager()
        fake_file_handle = StringIO()
        converter = TextConverter(resource_manager, fake_file_handle)
        page_interpreter = PDFPageInterpreter(resource_manager, converter)
        page_interpreter.process_page(page)
        text = fake_file_handle.getvalue()
        print(text)
        print("\n")
#20頁大概3~5秒
# Out:
# 一、第 1 屆第 1 次定期大會第 27 次會議 （中華民國 100 年 5 月 16 日上午 8 時分） 主席（許議長崑源）： 向大會報告，今天上午的議程是市政總質詢，第一位請蘇議員炎城開始質詢。 蘇議員炎城： 大會主席許議長、陳市長、各位局長、各位議員同仁以及記者先生、小姐，大家好。高雄縣市已經合併，陳市長一直強調「無縫接軌」，到目前為止，在各方面的交接、運作，大致上還算不錯；但是有一小部分，高雄縣、高雄市留下來的法令規範有不一樣的地方， 要如何做處理，我相信還有其他的問題，大家要再研議、協商，看要如何修改。高雄縣市合併以後， 長期照護協會要何去何從，我們都知道高雄市的法令規範和高雄縣的總是有一些差距，在這種情況下，有差距的部分要如何磨合、協調，才能在短期間進入狀況，本席在這裡有一些事情要請教各位局長們。 社會局局長，原高雄縣老人安養機構已面對一些問題，我在這裡和局長一起來研究，高雄市安養機構共有幾家？其中原高雄縣佔的比例是多少？ 安養機構可以凸顯一件事情，凡人都會年老，要把這些長輩送到哪裡， 這是大家關心的，在座的各位，總有一天也會面臨到這個問題，在整體的情況下，給予長輩們好的福利、提升品質，我相信這是大家的期待， 尤其這些長輩辛辛苦苦建立這個社會， 也付出他們的青春、時間、專業， 為我們的社會、政府、國家來努力，因為年紀也大了，他們一定會面臨到這些問題。 社會局蘇局長，安養機構共有幾家，你應該知道吧！高雄市共有幾家？ 高雄市應該比較知道，高雄縣有幾家？你知道嗎？ 主席（許議長崑源）： 社會局局長，請答覆。 社會局蘇局長麗瓊： 原高雄縣有 58 家。 蘇議員炎城： 高雄市呢？ 社會局蘇局長麗瓊： 高雄市大概有 85 家。 蘇議員炎城： 高雄市有這麼多嗎？ 社會局蘇局長麗瓊：
#
#
# ...

# %%
#pip install pdfminer.six 
for page in PDFPage.get_pages(fh, caching=True, check_extractable=True)

    resource_manager = PDFResourceManager()
    converter = TextConverter(resource_manager, fake_file_handle)
    page_interpreter = PDFPageInterpreter(resource_manager, converter)
    page_interpreter.process_page(page)
    text = fake_file_handle.getvalue()

# for page in PDFPage.get_pages(fh, caching=True, check_extractable=True)   =>      PDFPage.get_pages(file_pointer, set(), maxpages=0, password="", caching=True, check_extractable=True)

# resource_manager = PDFResourceManager()    =>  Create a PDF resource manager object that stores shared resources

#  converter = TextConverter(resource_manager, fake_file_handle)    =>     device = TextConverter(rsrcmgr, outfp, codec=codec, laparams=laparams, imagewriter=imagewriter)

#  page_interpreter = PDFPageInterpreter(resource_manager, converter)   =>    Processor for the content of a PDF page,     Create a PDF interpreter object

#  page_interpreter.process_page(page)    =>     Process each page contained in the document
#  text = fake_file_handle.getvalue()
# Out:
#   File "<ipython-input-6-9736ffb9ceee>", line 2
#     for page in PDFPage.get_pages(fh, caching=True, check_extractable=True)
#                                                                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# 可以參考 : https://github.com/pdfminer/pdfminer.six,  https://pdfminer-docs.readthedocs.io/

# %%
glob:  glob.glob("{}/*.pdf".format(pdf_path))

with open(csv_path, opMode, newline='', encoding='utf-8-sig') as csv_file:
    pdfName = os.path.basename(pdf_file)
    writer.writerow(['FileNo', 'FileName', 'Text'])                            
    #v.s.        writer.writerow([FSeqNo, pdfName, contain])

fake_file_handle = io.StringIO()  , text = fake_file_handle.getvalue()
yield text
# Out:
#   File "<ipython-input-5-7e98ad98350c>", line 8
#     fake_file_handle = io.StringIO()  , text = fake_file_handle.getvalue()
#                       ^
# SyntaxError: can't assign to function call
