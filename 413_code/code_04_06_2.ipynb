# %% [markdown]
# ### 分析 民主進步黨 與 台灣民眾黨
#
# > ### 4. 關聯圖

# %%
import pandas as pd 
df = pd.read_csv("data/10802_2020_party.csv") #匯資料
df["Post_Date"] = df["Date"].str.split(" ").str.get(0).str.title() #加Post_Date欄位
df['Post_Date'] = pd.to_datetime(df['Post_Date'])

# %% [markdown]
# ### 資料前處理
# 選出民進黨的發文，處理方式和上面一樣

# %%
import jieba
from tqdm import tqdm

df_green = df[df['Page_Name']=='民主進步黨'][0:30]
df_green_New = df_green[['Post_Date', 'Message']]
df_green_New = df_green_New.dropna()
df_green_New['Message']

doc_names = range(len(df_green_New))
text_list = list(df_green_New['Message'])
df_green_docs = pd.DataFrame(columns=['jieba_results'])
df_green_docs['jieba_results'] = df_green_docs['jieba_results'].astype('str')

for i in doc_names:
    words = jieba.cut(text_list[i], cut_all = False)
    text = ''
    for word in words:
        text = text + ' ' + str(word)
    s = pd.Series({'jieba_results': text})
    df_green_docs = df_green_docs.append(s, ignore_index=True)  
    
df_green_New.reset_index(inplace=True)  #不設定的話會有錯亂的情形，data對不起來
df_green_New['jieba_results'] = df_green_docs
df_green_New['df_class'] = 'green'
df_green_New.head()
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\User\AppData\Local\Temp\jieba.cache
# Loading model cost 0.688 seconds.
# Prefix dict has been built succesfully.
#    index  Post_Date                                            Message  \
# 0      3 2020-01-11                         《2020 台灣要贏 LET'S WIN 開票之夜》
# 1     10 2020-01-10  總統票3號蔡英文、賴清德，立委票請支持民主進步黨提名或推薦的候選人，第三張政黨票最重要，請集...
# 2     11 2020-01-07  #這是我的投票意志\n\n總統票3號、政黨票14號，\n3.14是圓周率，守護民主需要投票率...
# 3     14 2020-01-10  🔥蔡英文賴清德 #光復高雄 選前之夜🔥\n\n2020 高雄大贏！2020 台灣要贏！\n高...
# 4     19 2020-01-05  1月11日，我們一起回家投票！\n\n這一天的你，早起搭上返鄉的列車，檢查身份證是否帶上，我...
#
#                                        jieba_results df_class
# 0           《 2020   台灣 要贏   LET ' S   WIN   開票 之夜 》    green
# 1   總統票 3 號蔡 英文 、 賴清德 ， 立委 票 請 支持 民主 進步 黨 提名 或 推薦...    green
# 2   # 這是 我 的 投票 意志 \n \n 總統票 3 號 、 政黨票 14 號 ， \n ...    green
# 3   🔥 蔡 英文 賴清德   # 光 復 高雄   選前 之夜 🔥 \n \n 2020   ...    green
# 4   1 月 11 日 ， 我們 一起 回家 投票 ！ \n \n 這 一天 的 你 ， 早起 ...    green

# %% [markdown]
# 選出台灣民眾黨的發文，處理方式和上面一樣

# %%
df_white = df[df['Page_Name']=='台灣民眾黨'][0:30] #台灣基進

df_white_New = df_white[['Post_Date', 'Message']]
df_white_New = df_white_New.dropna()
df_white_New['Message']

doc_names = range(len(df_white_New))
text_list = list(df_white_New['Message'])
df_white_docs = pd.DataFrame(columns=['jieba_results'])
df_white_docs['jieba_results'] = df_white_docs['jieba_results'].astype('str')

for i in doc_names:
    words = jieba.cut(text_list[i], cut_all = False)
    text = ''
    for word in words:
        text = text + ' ' + str(word)
    s = pd.Series({'jieba_results': text})
    if(text=='NAN'):
        print(text_list[i])
    elif(text==''):
        print(text_list[i])
    df_white_docs = df_white_docs.append(s, ignore_index=True)  
    
df_white_New.reset_index(inplace=True)        
df_white_New['jieba_results'] = df_white_docs
df_white_New['df_class'] = 'white'
#df_white_New.head()

# %% [markdown]
# 合併上面兩個dataframe

# %%
mergeData = df_white_New.append(df_green_New)
mergeData = mergeData.dropna() #刪除有NAN值的data
#mergeData

# %% [markdown]
# ## TF-IDF

# %%
corpus = mergeData['jieba_results'].values.tolist()

# %%
# TF-IDF
# coding:utf-8  
from sklearn.feature_extraction.text import CountVectorizer  
vectorizer = CountVectorizer()  
X = vectorizer.fit_transform(corpus)  
word = vectorizer.get_feature_names()  

from sklearn.feature_extraction.text import TfidfTransformer  
transformer = TfidfTransformer()  
tfidf = transformer.fit_transform(X)

# %%
len(corpus)
features = tfidf.toarray()
labels = mergeData['Post_Date'].values
#labels

# %% [markdown]
# ### PCA

# %%
from pandas import DataFrame, read_csv
import numpy as np
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
transData = pca.fit_transform(features, labels)
type(transData)
mergeData['pca1'] = DataFrame(transData[:,0])
mergeData['pca2'] = DataFrame(transData[:,1])
#mergeData.head(150)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

textFrame = pd.DataFrame(features, columns = word)
textFrame
# Out:
#           00        10       100       103      1043       107        11  \
# 0   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.056448
# 1   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.042524  0.000000  0.000000  0.000000  0.000000  0.027433
# 5   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.029849
# 6   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 11  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 12  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 13  0.000000  0.095539  0.000000  0.000000  0.000000  0.000000  0.030817
# 14  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 15  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 16  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 17  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 18  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 19  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 20  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 21  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 22  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 23  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 24  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 25  0.000000  0.000000  0.056849  0.000000  0.000000  0.056849  0.000000
# 26  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 27  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.037900
# 28  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 29  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 30  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 32  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.115476
# 33  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 34  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.149557
# 35  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 36  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 37  0.072590  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 38  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 39  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.064779
# 40  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 41  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.069959
# 42  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 43  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.064779
# 44  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 45  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 46  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 47  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 48  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 49  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 50  0.092512  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 51  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 52  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.132723
# 53  0.255648  0.191252  0.000000  0.000000  0.000000  0.000000  0.061691
# 54  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 55  0.101020  0.000000  0.000000  0.000000  0.000000  0.000000  0.073132
# 56  0.000000  0.000000  0.000000  0.000000  0.100726  0.000000  0.000000
# 57  0.000000  0.000000  0.000000  0.105913  0.000000  0.000000  0.000000
# 58  0.000000  0.000000  0.000000  0.064964  0.000000  0.000000  0.000000
# 59  0.082672  0.000000  0.000000  0.000000  0.000000  0.000000  0.059849
#
#         1106      1131        12  ...       黨籍        黨能        黨詢        黨過  \
# 0   0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 3   0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.037895  ...  0.00000  0.000000  0.000000  0.000000
# 5   0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 6   0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 7   0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 11  0.000000  0.000000  0.000000  ...  0.00000  0.070917  0.000000  0.000000
# 12  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 13  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 14  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 15  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 16  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 17  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 18  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 19  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 20  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 21  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 22  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 23  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 24  0.000000  0.000000  0.000000  ...  0.06774  0.000000  0.000000  0.000000
# 25  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 26  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 27  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 28  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 29  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 30  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 31  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 32  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 33  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 34  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 35  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 36  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 37  0.000000  0.000000  0.072590  ...  0.00000  0.000000  0.000000  0.000000
# 38  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 39  0.000000  0.108169  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 40  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 41  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 42  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 43  0.000000  0.108169  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 44  0.000000  0.000000  0.261421  ...  0.00000  0.000000  0.086988  0.000000
# 45  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 46  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 47  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 48  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 49  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 50  0.000000  0.000000  0.092512  ...  0.00000  0.000000  0.000000  0.000000
# 51  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 52  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 53  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 54  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.161378
# 55  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 56  0.100726  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 57  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 58  0.000000  0.000000  0.000000  ...  0.00000  0.000000  0.000000  0.000000
# 59  0.000000  0.000000  0.082672  ...  0.00000  0.000000  0.000000  0.000000
#
#           黨選        黨黨        鼓勵       鼓吹        鼠年       龍壽橋
# 0   0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 2   0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 3   0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 5   0.000000  0.000000  0.000000  0.05488  0.000000  0.000000
# 6   0.000000  0.000000  0.000000  0.00000  0.293743  0.000000
# 7   0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 9   0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 11  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 12  0.000000  0.000000  0.000000  0.00000  0.000000  0.080035
# 13  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 14  0.000000  0.000000  0.058599  0.00000  0.000000  0.000000
# 15  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 16  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 17  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 18  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 19  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 20  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 21  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 22  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 23  0.000000  0.033397  0.000000  0.00000  0.000000  0.000000
# 24  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 25  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 26  0.000000  0.122194  0.113432  0.00000  0.000000  0.000000
# 27  0.000000  0.000000  0.058748  0.00000  0.000000  0.000000
# 28  0.069581  0.000000  0.000000  0.00000  0.000000  0.000000
# 29  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 30  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 31  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 32  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 33  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 34  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 35  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 36  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 37  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 38  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 39  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 40  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 41  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 42  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 43  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 44  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 45  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 46  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 47  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 48  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 49  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 50  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 51  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 52  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 53  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 54  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 55  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 56  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 57  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 58  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 59  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
#
# [60 rows x 3201 columns]

# %%
allF = features.flatten()
nonZero = allF[np.nonzero(allF)]
m = np.median(nonZero)

# %%
allF[np.nonzero(allF)]
# Out:
# array([0.0564482 , 0.09425783, 0.1037832 , ..., 0.09993727, 0.0654075 ,
#        0.08267239])

# %%
plt.hist(nonZero, bins=500)
plt.show()
m
# Out:
# 0.06917233475992222

# %%
m = 0.1
dataset = list()
for i in range(len(features)):
    temp = textFrame.columns.values[tuple([textFrame.iloc[i] >= m])]  #有tuple error
    dataset.append(temp.tolist())

# %%
for i in range(len(features)):
    print(dataset[i])
# Out:
# ['588', '706', '一個', '一場', '一舉', '一路上', '傳統', '優勢', '創立僅', '勇氣', '卓越', '受到', '大選中', '寧靜', '席進', '得票率', '志工', '成功', '捷徑', '推動', '改變', '政治', '文化', '本次', '汗水', '沒有', '淚水', '深知', '深重', '準檢視', '眾人', '精彩', '興政黨', '若要', '軍國會', '送入', '這場', '革命', '高標']
# ['上線', '大家', '如何', '覺得', '黨徽']
# ['158', '上工', '不會成', '主動', '人賴', '今日', '任黨團', '其祿', '協商', '各黨', '嗡嗡', '嗡開始', '回到', '將以', '張其祿', '承諾', '擔任', '擔綱', '民眾', '法案', '由賴', '確定', '總召', '總召出', '總召張', '總召賴', '肩上', '自己', '萬餘', '選舉', '重擔', '開始', '革命', '香伶', '香伶擔', '黨團', '黨會']
# ['一步', '世界', '以台灣', '共融', '台北市', '台灣', '台灣民眾', '國際', '姊妹市', '市政府', '布拉格', '我們', '才能', '整體', '朋友', '看到']
# ['我們', '海選', '證明']
# ['人民', '作主', '兩大黨', '出門', '利益', '前一天', '哪裡', '國家', '就是', '我們', '投票', '政治', '政黨', '歸隊', '民主', '真正', '選前', '還記', '革命']
# ['台灣民眾', '大家鼠', '所鼠', '抹紅', '民眾', '眾望', '自己', '行大運', '這次', '鼠年']
# ['之力', '例為', '保護', '保護別', '個案', '出現', '助人', '口罩', '各位', '就是', '就醫', '才能', '此外', '武漢', '消毒', '狀況', '疫情', '確診', '肺炎', '自助', '自己', '衛生', '資訊', '防疫']
# ['一個', '不是', '人民', '價值', '利益', '可以', '台灣', '因為', '就是', '弱勢', '成立', '我們', '所以', '政治', '政黨', '文化', '社會', '自由', '關懷']
# ['live', '全程', '台灣', '感恩', '感謝', '感謝民眾', '直播', '茶會', '選後記者', '開票']
# ['上午', '不足', '並不斷', '並無私', '並給予', '五名', '交換', '侃侃', '前輩', '前輩虛心', '創造合', '勉勵', '勳章', '受教', '向政壇', '國會', '學習', '寶貴', '專業', '強調民代', '必須', '感謝', '憂讒畏', '成為', '我們', '拜會', '指點', '攻擊', '政策', '新科', '會談', '柯建銘', '極力', '民意', '氣氛', '立院', '經驗', '虛心', '融洽', '許經驗', '請益', '謹記', '走出', '身上', '進化', '須以', '黨團']
# ['158', '不要', '中共', '事情', '候選人', '全台', '反民主', '取代', '口水', '口號', '同路人', '我們', '打著', '扯後腿', '批評', '瓜分', '競爭', '良性', '認為', '說法']
# ['不分', '利息', '大撒幣', '就是', '撒幣', '支票', '政見', '苗栗', '藍綠', '行政院', '財政紀律', '這些', '選前', '選舉']
# ['人民', '傲慢', '初衷', '利益', '因為', '國家', '我們', '政府', '政治', '政黨', '時候', '期盼', '民主', '為榮', '監督', '真正', '莫忘', '這會']
# ['中正', '之外', '創造', '台北市', '台灣民眾', '名單', '投給', '提名', '松山', '民眾', '發起', '立委', '第一波', '第七', '第三', '第五', '致詞', '選區']
# ['子來', '血滴']
# ['一方', '不同', '主席', '今日', '以民眾', '價值', '公平', '分區', '台灣民眾', '名單', '國民黨', '強調', '形態', '意識', '我們', '提出', '政治', '更加', '本黨', '民眾', '治理']
# ['下標', '兩岸', '手法', '抹紅', '支持', '曲解', '查核', '柯文', '汪浩及', '海峽', '網友', '自由', '選前', '部分']
# ['不是', '全民', '台灣', '台灣民眾', '各種', '問題', '希望', '我們', '準備', '相信', '答案', '組黨', '統獨', '總統', '至於', '解決', '選出', '關於']
# ['上線', '大家', '如何', '覺得', '黨徽']
# ['一起', '之夜', '出來', '創造', '台灣民眾', '大家', '收看', '歡迎', '歷史', '民眾', '直播', '第一次', '這是', '選前']
# ['上入', '上線', '全面', '台灣民眾', '官方', '實現', '徵選', '我們', '改變', '政治', '政黨', '文化', '正式', '相信', '網站', '開放']
# ['人權', '台灣民眾', '呼籲', '條例', '港府', '港民', '自由', '蒙面', '香港', '香港政府']
# ['2017', '一家', '主權', '兩岸', '十二天', '台灣', '吳秘', '就是', '態度', '我們', '政黨', '書長', '理解', '統獨', '統獨立場', '認同', '這種', '需要']
# ['一個', '主席', '人民', '保持', '參選', '友善', '台北市', '團隊', '意志', '成功', '政黨', '有民進', '柯文', '沒有', '理性', '確實', '論辯', '資源', '透過', '連任']
# ['65', 'do', 'right', '以上', '億元', '報告', '就是', '敬老', '服務', '機關', '照顧', '發放', '縣市', '老人', '重陽']
# ['23', '50', '59', 'callforpapers', 'com', 'gmail', 'tpp', '主席', '作品', '傑出', '創造奇', '只能', '只要', '召喚', '回合', '大家', '天下', '完善', '客氣', '寄至', '將設計', '廣納', '張獎', '徵選', '志士', '意見', '掏錢', '深感', '獎勵', '獎金', '獲得', '男人', '發動', '籌備', '結束', '給予', '萬總獎', '規章', '設計', '許多', '足夠', '辦法', '連續', '那個', '除了', '難得', '高額', '魔法', '黨徽', '黨黨', '鼓勵']
# ['z9', '兩個', '勢力', '可以', '吳達偉', '問題', '囤房', '小孩', '就是', '居住', '市場', '希望', '強調', '情況', '房稅', '板橋', '正義交', '第三', '給民眾', '青年', '青年人', '體制']
# ['不給', '先生', '加護', '包容', '十年', '參訪團', '同仁', '所有', '所謂', '所述', '文中', '本黨', '極為', '病房', '聲譽', '醫護', '醫院', '面子']
# ['bit', 'com', 'facebook', 'https', 'ly', 'www', '不分區']
# ['2020', 'let', 'win', '之夜', '台灣', '要贏', '開票']
# ['14', '不厭', '不要', '世界', '候選人', '全世界', '其煩', '出來', '分票', '各位', '張政黨票', '我要', '推薦', '提名', '支持', '民主', '灣人', '看台', '第三', '總統票', '聲音', '聽到', '號蔡', '賴清德', '這場', '進步', '選戰', '選擇', '重要', '隊友', '集中力量']
# ['11', '14', '一份', '一票', '不論', '做小英', '助力', '勢力將', '台灣', '回家', '因為', '圓周率', '在意', '將到', '小心', '希望', '想以', '想要', '我會', '投下', '投票', '投票率', '政黨票', '日即', '殿堂', '民主', '珍惜', '理由', '自由民主', '行動', '親共', '親友', '週六', '還是']
# ['2020', '一起', '三張', '並且', '保衛', '全台灣', '八仙', '分享', '勝利', '台灣', '團結', '堅強', '大家', '好友', '或是', '找回', '決心', '現場', '看見', '給親', '總統', '自由民主', '英文', '要贏', '贏得', '過海', '關頭', '顧台灣', '高雄', '高雄人', '高雄大贏', '高雄守護', '高雄顧']
# ['11', '一天', '一起', '三步', '不見', '作出', '列車', '回去', '回家', '國家', '堅定', '家人', '將會', '帶上', '我們', '所愛的', '投好', '搭上', '政黨票', '故鄉', '早起', '是否', '檢查', '民主', '決定', '看看', '知道', '票過', '見見', '許久', '身份', '返鄉', '進步', '重要', '風景']
# ['wbsc', '一級', '不起', '中華隊', '今晚', '來源', '台灣', '國際賽', '夜晚', '奧運門票', '完封', '帶來', '影像', '愉快', '感謝', '成績', '日本', '期待', '活躍表現', '爭取', '獲得', '球迷', '精采', '能夠', '英雄', '資格', '這是', '韓國', '首次']
# ['中常', '出席', '常委', '感謝', '清德', '當選人賴', '總統', '致意', '英文', '辛勞', '選戰']
# ['1229', '下架', '之夜', '保台', '北平', '吳斯懷', '東路', '護國', '護國級', '陣容']
# ['14', '一個', '一起', '不可', '之夜', '今晚', '出來', '勝利', '台中', '台灣', '回家', '投票', '民主', '續約', '英德', '英文', '號蔡', '賴清德', '贏得', '進步', '選前', '選票續', '隊長']
# ['1131', 'https', 'iing', 'line', 'posts', 'spicytaiwan', 'tw', '一個', '你們', '倒數', '候選人', '分享', '加入', '勝利', '卓榮泰', '南投', '台北', '大家', '大掃街', '好友', '對手', '小英', '幫忙', '廣告', '彰化', '支持', '新北', '最後幾天', '民進', '熱烈', '由小英', '眼部', '結起', '給優秀', '給親', '線點', '總統', '總統候', '英粉', '賴清德', '車掃路', '車掃路線', '車隊', '這最後關', '這邊', '那麼', '關頭', '陪同', '領軍', '頭團']
# ['chang', 'chen', 'chien', 'fb', 'jen', 'liang', 'ps', 'weng', '位置', '來會場', '公園', '吳秉叡', '呂孫', '呂孫綾', '外縣', '建仁', '快來', '快點', '愈來', '愛台', '搶個', '新莊', '方便', '晚會', '朋友', '活動', '直播', '粉絲頁', '翁章', '草坪', '蘇巧慧', '蘇貞昌', '號吳秉叡', '號呂孫', '號民進', '號蘇巧慧', '趕快', '造勢', '開始', '陽光']
# ['36sipd5', '一票', '一起', '不分', '不曾', '主人', '作伙來', '前行', '勇敢', '台灣', '國家', '壯大台灣', '家園', '年紀', '感謝', '我要', '投好', '投票', '換上', '放棄', '政黨票', '權利', '民主', '特效', '票過', '總統候', '自由民主', '行使', '賴清德', '路上', '這週', '進步']
# ['三讀', '反滲', '召開', '林飛帆', '民進', '秘書長', '記者', '透法', '通過', '針對']
# ['1131', 'https', 'iing', 'line', 'posts', 'spicytaiwan', 'tw', '一個', '你們', '倒數', '候選人', '分享', '加入', '勝利', '卓榮泰', '南投', '台北', '大家', '大掃街', '好友', '對手', '小英', '幫忙', '廣告', '彰化', '支持', '新北', '最後幾天', '民進', '熱烈', '由小英', '眼部', '結起', '給優秀', '給親', '線點', '總統', '總統候', '英粉', '賴清德', '車掃路', '車掃路線', '車隊', '這最後關', '這邊', '那麼', '關頭', '陪同', '領軍', '頭團']
# ['12', '20', '上線', '保台', '外套', '夾克', '民主', '民進', '而戰', '護國', '飛行']
# ['152', 'ahueimoto', 'ahueipower', 'al3kuwl', 'com', 'cx', 'facebook', 'groups', 'https', 'ig', 'instagram', 'line', 'nav', 'www', '一下', '全國矚', '公明', '千萬', '嘉義市', '大嘉義之夜', '委員', '惠粉', '抓緊', '抵達', '指南', '有空', '東區', '正副', '現場', '白色', '目的', '社團', '立法', '粉色', '級嘉賓', '總部', '色票', '襄盛舉', '許多', '賴神', '選票', '還沒', '重量', '錯過', '阿惠']
# ['一起', '下架', '促統', '候選人', '全民', '台灣', '吳斯懷', '國民黨', '外交', '安全']
# ['14', '177', '19', 'fensi', 'only', 'ting', 'twinkling', 'you', '下午', '之夜', '停車場', '六合', '前來', '卡西', '台語', '各位朋友', '基隆', '基隆市', '天后', '支持', '日期', '星期四', '東明路', '歌王', '甜心', '相挺', '翁立友', '萬人', '蓉蓉', '蔡適', '號旁', '謝金晶', '適應', '金曲']
# ['chatbot', 'kuanbiling', '一同', '一封信', '一起', '不分', '互動', '佩玲', '保台灣', '信給', '出席', '區候', '堅守', '孩子', '宣傳', '專案', '影片', '成員', '搭配', '收信', '政黨票', '文嘉', '洪申翰', '熱情', '用政黨', '用政黨票', '發布', '發言人', '票護國', '秘書長', '管碧玲', '給台灣', '而戰', '聊天', '臉書', '號召', '護國會', '讓民眾', '透過', '選人']
# ['ing', 'tsai', 'wen', '一票', '三步', '下個', '不是', '保台', '做事', '做小英', '全世界', '加薪', '努力', '口號', '四小龍', '四年', '國家', '國家力', '平等', '情守', '成績', '我們', '抗紅色', '拚經濟', '推薦', '政黨票', '是民進', '沒有界線', '減稅', '滲透', '瘟疫', '福利', '第一', '給台灣', '蘇貞昌院', '走進', '這幾個', '選民進', '防堵', '顧主權']
# ['1229', '2zi1av1', 'ft', 'gigo', '交響', '何欣穗', '余天', '入場', '全程', '凱旋', '動員', '北平', '北路', '吳怡農', '唱將', '大凱旋', '大型', '完整', '導寺', '得到', '感受', '戰將', '捷運站', '排除', '最強', '杭州', '東路', '林昶佐', '柏惟', '樂團', '洪慈庸', '火器', '現場', '登場', '總部前', '英文', '萬難', '號至', '表演', '賴品', '迎接', '近善', '金曲', '閃靈', '震撼']
# ['一支', '一直', '不容', '作戰', '共同', '博文', '口罩', '召開', '周江杰', '影像', '提供', '發言人何', '直播', '粉絲團', '網路', '視同', '記者', '謠言', '進步', '防疫']
# ['11', '2020', 'ing', 'tsai', 'wen', '一起', '今晚', '候選人', '做小英', '台灣', '各位', '哪裡', '國家', '孩子', '守護', '投票', '推薦', '提名', '政黨票', '方向', '明天', '未來', '民主', '決定', '無論', '用三張', '立委', '總統', '英文', '賴清德', '進步', '選民進', '選票', '隊友']
# ['00', '10', '18', '19', '77', '一分', '下午', '中洲', '保衛', '公館', '凱道', '凱達格蘭', '台中場', '台灣', '場停', '場勝利', '大道', '小英為', '往前走', '手上', '挺直', '捍衛', '新北場', '會繼續', '板橋區', '棒球', '每一張', '民主', '決心', '維持', '腰桿', '臉書大頭', '英文', '街民權', '議會路', '路口', '車場', '迎接', '這塊', '這張票', '防衛', '集中力量', '高雄場', '鳳山區', '點擊']
# ['一代', '三十二', '今天', '作為', '入陣', '內部', '其實', '出生', '到民進', '前人', '努力', '參與', '台灣面', '困境', '執政', '多重', '對話', '小組', '成果', '我願意', '接下', '擴張', '日子', '期待', '未能', '林飛帆', '秘書長', '篳路', '職務', '臨中國', '藍縷', '解嚴', '轉型', '這個', '週年', '過程', '雖然', '黨過']
# ['00', '2020', 'han', 'sun', '一個', '三張', '倒數', '公園', '前廣場', '勝利', '卓榮泰', '台灣', '吳玉琴', '回家', '守住', '宜蘭要', '宜蘭運動', '愛台灣', '戰力', '投票', '日期', '時刻', '晚會', '最後黃金', '林佳龍', '林楚茵', '歐珀', '洪申翰', '活動', '游錫堃', '票票', '英德', '英文', '莊瑞雄', '護主權', '返鄉', '造勢', '選票護', '關鍵', '雄有', '集中', '體育館']
# ['1043', '1106', '600', 'ilesttempsdevisiterta', 'it', 'now', 'sekarangsaatnyamengunjungitaiwan', 'time', 'timetovisittaiwan', 'to', 'visit', 'wan', '一位', '下半年', '世界各地', '人數', '人次', '佳樂水', '來台', '光是', '出走', '可見', '台國外', '台湾', '台灣', '品質', '四位', '國內', '國旅', '增加', '太麻里', '好玩', '安排', '小覷', '島內', '帶領', '拍板', '探索', '方案', '旅人', '旅客', '旅行', '旅遊', '暢遊', '李問', '李明俐', '李晏榕', '潛力', '澄清湖', '澎湖', '率隊', '由民進', '秋冬', '穩健', '美景', '腳步', '自由', '親身', '觀光', '觀光客', '趁現', '越來', '越多來', '踏上', '遊獎勵', '適合', '體驗']
# ['103', '2azhx1h', '一生', '主體', '享嵩壽', '仙逝', '全體', '前輩', '前輩致', '前途', '即使', '台灣', '台灣魂', '史明', '喚起', '奉獻', '引領', '思潮', '懷念', '拐杖', '挺起', '敬悼', '敬意', '昨晚', '最高', '歐吉桑', '決議文', '沉睡', '深化', '無私', '獨立', '緬懷', '耕耘', '腰桿', '進步', '革命者']
# ['2020', '一票', '三重', '余天', '保台灣', '億多', '新北', '新莊區', '板橋', '護國會']
# ['不同', '並呼籲', '也將', '住民', '保台', '候選人羅', '北平', '南洋', '印尼', '及菲律賓', '各業', '各行', '回顧民', '國籍', '實事', '把握', '明年', '東路', '柬埔寨', '民政', '泰國', '用心', '美玲', '詳情', '護國', '越南']

# %% [markdown]
# ### apriori 關聯圖

# %%
# Apriori: https://rasbt.github.io/mlxtend/user_guide/frequent_patterns/apriori/
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
graph = df.T
graph.columns = mergeData['Post_Date']

# %%
graph.tail()
# Out:
# Post_Date  2020-01-11  2020-01-30  2020-01-13  2020-01-15  2019-11-19  \
# 黨會              False       False        True       False       False
# 黨過              False       False       False       False       False
# 黨黨              False       False       False       False       False
# 鼓勵              False       False       False       False       False
# 鼠年              False       False       False       False       False
#
# Post_Date  2020-01-10  2020-01-23  2020-01-30  2019-08-06  2020-01-11  ...  \
# 黨會              False       False       False       False       False  ...
# 黨過              False       False       False       False       False  ...
# 黨黨              False       False       False       False       False  ...
# 鼓勵              False       False       False       False       False  ...
# 鼠年              False        True       False       False       False  ...
#
# Post_Date  2019-12-21  2020-01-31  2020-01-10  2020-01-10  2019-07-15  \
# 黨會              False       False       False       False       False
# 黨過              False       False       False       False        True
# 黨黨              False       False       False       False       False
# 鼓勵              False       False       False       False       False
# 鼠年              False       False       False       False       False
#
# Post_Date  2020-01-09  2019-08-04  2019-09-21  2019-12-11  2019-12-23
# 黨會              False       False       False       False       False
# 黨過              False       False       False       False       False
# 黨黨              False       False       False       False       False
# 鼓勵              False       False       False       False       False
# 鼠年              False       False       False       False       False
#
# [5 rows x 60 columns]

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

minsup = 0.001
apriori(graph, min_support = minsup, use_colnames=True)
# Out:
#       support                                           itemsets
# 0    0.035199                              (2020-01-11 00:00:00)
# 1    0.004513                              (2020-01-30 00:00:00)
# 2    0.033394                              (2020-01-13 00:00:00)
# 3    0.014440                              (2020-01-15 00:00:00)
# 4    0.002708                              (2019-11-19 00:00:00)
# ..        ...                                                ...
# 413  0.001805  (2020-01-10 00:00:00, 2020-01-08 00:00:00, 202...
# 414  0.001805  (2020-01-10 00:00:00, 2020-01-08 00:00:00, 202...
# 415  0.001805  (2020-01-10 00:00:00, 2020-01-08 00:00:00, 202...
# 416  0.001805  (2020-01-10 00:00:00, 2020-01-08 00:00:00, 201...
# 417  0.001805         (2020-01-10 00:00:00, 2020-01-09 00:00:00)
#
# [418 rows x 2 columns]

# %%
result = apriori(graph, min_support = minsup)
result
# Out:
#       support              itemsets
# 0    0.035199                   (0)
# 1    0.004513                   (1)
# 2    0.033394                   (2)
# 3    0.014440                   (3)
# 4    0.002708                   (4)
# ..        ...                   ...
# 413  0.001805  (34, 38, 41, 52, 31)
# 414  0.001805  (32, 38, 41, 52, 53)
# 415  0.001805  (32, 38, 41, 52, 55)
# 416  0.001805  (33, 38, 41, 46, 52)
# 417  0.001805  (33, 38, 52, 53, 55)
#
# [418 rows x 2 columns]

# %%
rules = association_rules(result, metric="confidence", min_threshold=0.0)
rules.head()
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0         (0)         (5)            0.035199            0.017148  0.001805
# 1         (5)         (0)            0.017148            0.035199  0.001805
# 2         (0)         (8)            0.035199            0.017148  0.002708
# 3         (8)         (0)            0.017148            0.035199  0.002708
# 4         (0)        (21)            0.035199            0.014440  0.002708
#
#    confidence      lift  leverage  conviction
# 0    0.051282  2.990553  0.001201    1.035979
# 1    0.105263  2.990553  0.001201    1.078307
# 2    0.076923  4.485830  0.002104    1.064756
# 3    0.157895  4.485830  0.002104    1.145702
# 4    0.076923  5.326923  0.002199    1.067690

# %%
rules = association_rules(result, metric="lift", min_threshold=1.2)
rules.head()
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0         (0)         (5)            0.035199            0.017148  0.001805
# 1         (5)         (0)            0.017148            0.035199  0.001805
# 2         (0)         (8)            0.035199            0.017148  0.002708
# 3         (8)         (0)            0.017148            0.035199  0.002708
# 4         (0)        (21)            0.035199            0.014440  0.002708
#
#    confidence      lift  leverage  conviction
# 0    0.051282  2.990553  0.001201    1.035979
# 1    0.105263  2.990553  0.001201    1.078307
# 2    0.076923  4.485830  0.002104    1.064756
# 3    0.157895  4.485830  0.002104    1.145702
# 4    0.076923  5.326923  0.002199    1.067690

# %%
rules["antecedant_len"] = rules["antecedents"].apply(lambda x: len(x))
rules.head()
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0         (0)         (5)            0.035199            0.017148  0.001805
# 1         (5)         (0)            0.017148            0.035199  0.001805
# 2         (0)         (8)            0.035199            0.017148  0.002708
# 3         (8)         (0)            0.017148            0.035199  0.002708
# 4         (0)        (21)            0.035199            0.014440  0.002708
#
#    confidence      lift  leverage  conviction  antecedant_len
# 0    0.051282  2.990553  0.001201    1.035979               1
# 1    0.105263  2.990553  0.001201    1.078307               1
# 2    0.076923  4.485830  0.002104    1.064756               1
# 3    0.157895  4.485830  0.002104    1.145702               1
# 4    0.076923  5.326923  0.002199    1.067690               1

# %%
out = rules[ (rules['antecedant_len'] >= 2) &
       (rules['confidence'] > 0.75) &
       (rules['lift'] > 1.2) ]
out.head()
# Out:
#     antecedents consequents  antecedent support  consequent support   support  \
# 330     (1, 26)        (19)            0.001805            0.004513  0.001805
# 332    (26, 19)         (1)            0.001805            0.004513  0.001805
# 337      (8, 3)        (18)            0.001805            0.016245  0.001805
# 342      (8, 3)        (23)            0.001805            0.016245  0.001805
# 344     (3, 23)         (8)            0.001805            0.017148  0.001805
#
#      confidence        lift  leverage  conviction  antecedant_len
# 330         1.0  221.600000  0.001797         inf               2
# 332         1.0  221.600000  0.001797         inf               2
# 337         1.0   61.555556  0.001776         inf               2
# 342         1.0   61.555556  0.001776         inf               2
# 344         1.0   58.315789  0.001774         inf               2

# %%
support = rules['support']
confidence = rules['confidence']
plt.scatter(support, confidence, alpha=0.5, marker="*")
plt.xlabel('support')
plt.ylabel('confidence') 
plt.show()

# %%
len(rules)
rules['antecedents'].head()
# Out:
# 0    (0)
# 1    (5)
# 2    (0)
# 3    (8)
# 4    (0)
# Name: antecedents, dtype: object

# %%
import networkx as nx
G = nx.DiGraph()
for i in range(len(mergeData)):
    G.add_node(i)
for i in range(len(rules['antecedents'])):
    currentFrom = list(rules['antecedents'][i])
    currentTo = list(rules['consequents'][i])
    for j in range(len(currentFrom)):
        G.add_edge(currentFrom[j], currentTo[0])

# %%
nodeListA = mergeData.index[mergeData['df_class'] == 'white'].tolist()
nodeListB = mergeData.index[mergeData['df_class'] == 'green'].tolist()
plt.figure(figsize=(20,20))

# positions for all nodes
pos = nx.spring_layout(G)

# nodes
nx.draw_networkx_nodes(G, pos, nodelist=nodeListA,node_color="blue", node_size=1000)
nx.draw_networkx_nodes(G, pos, nodelist=nodeListB,node_color="red",node_size=1000)
nx.draw_networkx_edges(G, pos, width=3,edge_color='gray')

# labels
nx.draw_networkx_labels(G,pos,font_size=20,font_family='sans-serif')
nx.draw(G, with_labels=True)

plt.axis('off')
plt.savefig("img/weighted_graph.png") # save as png

plt.show() # display
